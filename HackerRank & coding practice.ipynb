# %%
#https://www.hackerrank.com/challenges/diagonal-difference/problem?isFullScreen=true

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'diagonalDifference' function below.
#
# The function is expected to return an INTEGER.
# The function accepts 2D_INTEGER_ARRAY arr as parameter.
#

def diagonalDifference(arr):
    # Write your code here
    sum_l_r=0
    sum_r_l=0
    mid_term=0
    for i in range(len(arr)):
        for j in range(len(arr[i])):
            if i==j:
                sum_l_r+=arr[i][j]
                if (len(arr)%2!=0) and (i==((len(arr)//2))):
                    mid_term = arr[i][j]
                    #print(mid_term)
            elif i==len(arr)-(j+1):
                #print(i,(len(arr)-(j+1)),arr[i][j])
                sum_r_l+=arr[i][j]
    sum_r_l=sum_r_l+mid_term
    print(sum_l_r,sum_r_l,)
    return abs(sum_l_r-sum_r_l)
        

if __name__ == '__main__':

    n = int(input().strip())

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))
    print(arr)

    result = diagonalDifference(arr)
    print(result)

# %%
def diagonalDifference(arr):
    length=len(arr)
    sum_l_r=0
    sum_r_l=0
    for i in range(length):
        sum_l_r+=arr[i][i]
        sum_r_l+=arr[i][length-i-1]
    return abs(sum_l_r-sum_r_l)

# %%
#https://www.hackerrank.com/challenges/text-alignment/problem?isFullScreen=true

#Replace all ______ with rjust, ljust or center. 

thickness =5  #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    #print((c*i))
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))
#Top Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).center(thickness*6)) 

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6)) 

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).rjust(thickness)+c+(c*(thickness-i-1)).ljust(thickness)).rjust(thickness*6))
# Out:
#     H
#    HHH
#   HHHHH
#  HHHHHHH
# HHHHHHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#                     HHHHHHHHH
#                      HHHHHHH
#                       HHHHH
#                        HHH
#                         H

# %%
def print_rangoli(size):
    # your code goes here
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    my_list = []
    
    for i in range(size):
        s = "-".join(alphabet[size - 1 : size - 1 - i : -1] + alphabet[size - i - 1: size])
        my_list.append(s.center(4 * size - 3, "-"))
    
    print("\n".join(my_list + my_list[-2::-1]))
        
if __name__ == '__main__':
    #n = int(input())
    print_rangoli(5)
# Out:
# --------e--------
# ------e-d-e------
# ----e-d-c-d-e----
# --e-d-c-b-c-d-e--
# e-d-c-b-a-b-c-d-e
# --e-d-c-b-c-d-e--
# ----e-d-c-d-e----
# ------e-d-e------
# --------e--------

# %%
#https://www.hackerrank.com/challenges/staircase/problem?isFullScreen=true
# This is a staircase of size n=4 :

#    #
#   ##
#  ###
# ####


def staircase(n):
    # Write your code here
    for i in range(1,n+1):
        space=" "*(n-i)
        char="#"*i
        print(space+char)
        
if __name__ == '__main__':
    n = int(input().strip())

    staircase(n)
# Out:
# 4
#    #
#   ##
#  ###
# ####

# %%
#https://www.hackerrank.com/challenges/mini-max-sum/problem?isFullScreen=true

# Given five positive integers, find the minimum and maximum values that can be calculated by summing exactly four of the five integers. Then print the respective minimum and maximum values as a single line of two space-separated long integers.

# Example

# arr=[1 3 5 7 9]

# The minimum sum is 1+2+5+7=16  and the maximum sum is 3+5+7+9=24 . The function prints

# 16 24

# %%
arr=[1,2,3,4,5]
arr=sorted(arr)
print(arr)
max_val=arr[-1]
print(max_val)
second_max_val=arr[-2]
print(second_max_val)
mid_sum=sum(arr[:-2])
print(mid_sum)
# Out:
# [1, 2, 3, 4, 5]
# 5
# 4
# 6

# %%
arr.remove(2)

# %%
arr
# Out:
# [1, 3, 4, 5]

# %%
def miniMaxSum(arr):
    # Write your code here
    sum_list=[]
    for i in arr:
        arr1=arr.copy()
        arr1.remove(i)##just remove nota ssign
        #print(f"{sum(arr1)}")
        sum_list.append(sum(arr1))
    print(f"{min(sum_list)} {max(sum_list)}")   
        
if __name__ == '__main__':

    arr = list(map(int, input().rstrip().split()))

    miniMaxSum(arr)
# Out:
# 1 2 3 4 5
# 10 14

# %%
#https://www.hackerrank.com/challenges/birthday-cake-candles/problem?isFullScreen=true
#
#You are in charge of the cake for a child's birthday. You have decided the cake will have one candle for each year of 
#their total age. They will only be able to blow out the tallest of the candles. Count how many candles are tallest.

#candles=[4 4 1 3]
#The maximum height candles are  units high. There are  of them, so return .

# The maximum height candles are  units high. There are  of them, so return .

# Function Description

# Complete the function birthdayCakeCandles in the editor below.

# birthdayCakeCandles has the following parameter(s):

# int candles[n]: the candle heights
    
    
#  Returns

# int: the number of candles that are tallest   


def birthdayCakeCandles(candles):
    # Write your code here
    return candles.count(max(candles))

# %%
#https://www.hackerrank.com/challenges/time-conversion/problem?isFullScreen=true

# Given a time in 12-hour AM/PM format, convert it to military (24-hour) time.

# Note: - 12:00:00AM on a 12-hour clock is 00:00:00 on a 24-hour clock.
# - 12:00:00PM on a 12-hour clock is 12:00:00 on a 24-hour clock.


S="12:01:00PM"
Return '12:01:00'.

S="12:01:00AM"
Return '00:01:00'.

# %%
#|#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'timeConversion' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#

def timeConversion(s):
    # Write your code here
    if( s[-2:]=='AM' )  and (s[:2]=='12'):
        s=s.split(":")
        s[0]="00"
        right_time=":".join(s).replace("AM",'')
    elif ( s[-2:]=='AM' ) and (int(s[:2])<12):
        right_time=s.replace("AM",'')
    elif ( s[-2:]=='PM' )  and (s[:2]=='12'):
        right_time=s.replace("PM",'')
    elif ( s[-2:]=='PM' ) and (int(s[:2])<12):
        s=s.split(":")
        s[0]=str(int(s[0])+12)
        right_time=":".join(s).replace("PM",'')
    return right_time
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = timeConversion(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
# Solve the problem [Python]
# Given an array of integers arr and an integer k, create a boolean function that checks
# whether if there exist two elements in arr such that we get k when we add them together.

# Example 1:

# Input: arr = [4, 5, 1, -3, 6], k = 11

# Output: true

# Explanation: 5 + 6 is equal to 11

# Example 2:

# Input: arr = [4, 5, 1, -3, 6], k = -2

# Output: true

# Explanation: 1 + (-3) is equal to -2

# Example 3:

# Input: arr = [4, 5, 1, -3, 6], k = 8

# Output: false

# Explanation: there is no pair that sums up to 8

# Parameters:
#  arr: List[int]
#  k: int
# return type: bool

def findPair(arr, k):
    # your code here
    flag=False
    for i in arr:
        arr1=arr.copy()
        arr1.remove(i)
        if k-i in arr1:
            flag=True
            break
            
        else:
            flag=False
            
    return flag

# %%
# Task
# Given  sets of integers, M and N, print their symmetric difference in ascending order. The term symmetric difference indicates those values that exist in either  or  but do not exist in both.

# Input Format

# The first line of input contains an integer,M .
# The second line contains  M space-separated integers.
# The third line contains an integer, N.
# The fourth line contains  space-separated M integers.

# Output Format

# Output the symmetric difference integers in ascending order, one per line.

# Sample Input

# STDIN       Function
# -----       --------
# 4           set a size M = 4
# 2 4 5 9     a = {2, 4, 5, 9}
# 4           set b size N = 4
# 2 4 11 12   b = {2, 4, 11, 12}


# Sample Output

# 5
# 9
# 11
# 12

if __name__ == '__main__':
 m=int(input())
 m_set=set(list(map(int,input().split())))
 n=int(input())
 n_set=set(list(map(int,input().split())))
 set_diff=[]
 set_diff.extend(list(m_set.difference(n_set)))
 set_diff.extend(list(n_set.difference(m_set)))
 for i in (sorted(set_diff)):
     print(i)

# %%
#https://www.hackerrank.com/challenges/the-minion-game/problem?isFullScreen=true

def minion_game(s):
    # your code goes here
    kevin=[]
    stuart=[]
    n=len(s)
    for i in range(n):
        for j in range(i+1,n+1):
            if s[i:j][0] in (['A','E','I','O','U']):
                kevin.append(s[i:j])
            else:
                stuart.append(s[i:j])
    #print(kevin)
    #print(stuart)
    k_Score=sum([kevin.count(i) for i in set(kevin)])
    s_Score=sum([stuart.count(i) for i in set(stuart)])
    
    if k_Score>s_Score:
        print(f"Kelvin {k_Score}")
    elif k_Score<s_Score:
         print(f"Stuart {s_Score}")
    else:
        print("Draw")           
        

if __name__ == '__main__':
    s = input()
    minion_game(s)
# Out:
# BAANANAS
# Kelvin 19

# %%
##this is best version
def minion_game(S):
    # Initialize scores for Kevin and Stuart
    kevin_score = 0
    stuart_score = 0
    
    # Length of the string
    n = len(S)
    
    # Loop through each character in the string
    for i in range(n):
        # Calculate how many substrings start at position i
        # All substrings starting from position i will be counted as S[i:]
        # The number of substrings starting at index i is (n - i)
        if S[i] in 'AEIOU':  # Vowel
            kevin_score += n - i
        else:  # Consonant
            stuart_score += n - i
    
    # Determine the winner or if it's a draw
    if kevin_score > stuart_score:
        print(f"Kevin {kevin_score}")
    elif stuart_score > kevin_score:
        print(f"Stuart {stuart_score}")
    else:
        print("Draw")

# Test the function with the example string
minion_game("BANANA")

# %% [markdown]
# #https://www.hackerrank.com/challenges/merge-the-tools/problem?isFullScreen=true
#
# ![Merge%20the%20tool.PNG](attachment:Merge%20the%20tool.PNG)

# %%
s='AAABCADDEF'

chunks=[s[x:x+3] for x in range(0, len(s), 3)]
chunks
# Out:
# ['AAA', 'BCA', 'DDE', 'F']

# %%
set(chunks[0])
# Out:
# {'A'}

# %%
#This is also right but here the orrder is getting litttle wrong


def merge_the_tools(string, k):
    # your code goes here
    u=[string[x:x+k] for x in range(0, len(string), k)]
    for i in u:
        print("".join(set(i)))

if __name__ == '__main__':
    string, k = input(), int(input())
    merge_the_tools(string, k)
# Out:
# AABCAAADA
# 3
# AB
# CA
# DA

# %%
def merge_the_tools(string, k):
    # your code goes here
    u=[string[x:x+k] for x in range(0, len(string), k)]
    for i in u:
        new_string=[]
        #this will remove values which are duplicate but keep the order 
        [new_string.append(x) for x in i if x not in new_string]
                    
        print("".join(new_string))

if __name__ == '__main__':
    string, k = input(), int(input())
    merge_the_tools(string, k)

# %%
#https://www.hackerrank.com/challenges/itertools-product/problem?isFullScreen=true

# Enter your code here. Read input from STDIN. Print output to STDOUT
from itertools import product
A=list(map(int, input().rstrip().split()))
B=list(map(int, input().rstrip().split()))
prod=list(product(A,B))
print(*prod[:len(prod)]," ")
# Out:
# 1 2
# 3 4
# (1, 3) (1, 4) (2, 3) (2, 4)

# %%
n,m=[1,2]

# %%
n
# Out:
# 1

# %%
m
# Out:
# 2

# %%
#https://www.hackerrank.com/challenges/no-idea/problem?isFullScreen=true

# Enter your code here. Read input from STDIN. Print output to STDOUT
n,m= list(map(int,input().split()))
array=list(map(int,input().split()))
A=set(list(map(int,input().split())))
B=set(list(map(int,input().split())))

happines=0
for i in array:
    if i in A:
        happines+=1
    elif i in B:
        happines-=1
        
print(happines)


### **Optimized Approach**
#Using Python's `set` for \( A \) and \( B \) ensures efficient \( O(1) \) membership checks, making this approach \( O(n) \), where \( n \) is the length of the array.

# %%
#https://www.hackerrank.com/challenges/collections-counter/problem?isFullScreen=true
# collections.Counter()
# A counter is a container that stores elements as dictionary keys, and their counts are stored as dictionary values.

# Sample Code

# >>> from collections import Counter
# >>> 
# >>> myList = [1,1,2,3,4,5,3,2,3,4,2,1,2,3]
# >>> print Counter(myList)
# Counter({2: 4, 3: 4, 1: 3, 4: 2, 5: 1})
# >>>
# >>> print Counter(myList).items()
# [(1, 3), (2, 4), (3, 4), (4, 2), (5, 1)]
# >>> 
# >>> print Counter(myList).keys()
# [1, 2, 3, 4, 5]
# >>> 
# >>> print Counter(myList).values()
# [3, 4, 4, 2, 1]

if __name__=="__main__":
    x=int(input())
    shoe_size=list(map(int,input().split()))
    n_customers=int(input())
    total_money_earned=0
    for i in range(n_customers):
        size,price=list(map(int,input().split()))
        if size in shoe_size:
            total_money_earned+=price
            shoe_size.remove(size)
    print(total_money_earned)

# %%
set('aabbbccde')
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
## https://www.hackerrank.com/challenges/word-order/problem?isFullScreen=true

# Enter your code here. Read input from STDIN. Print output to STDOUT
def print_results(words):
    strs=[]
    result=[]
    #list(map(str,[words.count(i),strs.append(i) 
    for i in words:
        if i not in strs:
           result.append(words.count(i))
           strs.append(i)
           
    print(len(result))
    result=" ".join(list(map(str,result)))
    print(result)
    


if __name__=="__main__":
    n=int(input())
    words=[input() for i in range(n)]
    print_results(words)

    
    #this code have some time complexities issue. So now we will use the collection and counter

# %%
# this is faster
from collections import Counter

instances = int(input())
words = []

for i in range(instances):
    words.append(input())
    
ocurrencies = Counter(words)

print(len(ocurrencies))
print(" ".join(map(str, ocurrencies.values())))

# %%
#this will be fastest as we are using Dict
from collections import defaultdict

d = defaultdict(int)
n = int(input())

for _ in range(n):
    d[input()] += 1

print(len(d))
print(*d.values())

# %%
#https://www.hackerrank.com/challenges/piling-up/problem?isFullScreen=true

# Enter your code here. Read input from STDIN. Print output to S
def is_pile_possibe(blocks):
    prev_item=None
    result="Yes"
    while blocks:
        if blocks[0]>=blocks[-1]: 
            current_item=blocks.pop(0)       
        else:
            current_item=blocks.pop(-1)
        if prev_item:
            if current_item>prev_item:
                result = "No"
                break
        prev_item=current_item
        
    return result
        
if __name__=="__main__":
    n_test_cases=int(input())
    for i in range(n_test_cases):
        n=int(input())
        blocks=list(map(int,input().split(" ")))
        print(is_pile_possibe(blocks))

# %%
from collections import deque

num_test = int(input())

for _ in range(num_test):
    
    num_block = int(input())
    blocks = deque(map(int, input().split()))
    pile = []
    
    while blocks:
        
        if blocks[0] <= blocks[-1]:
            pile.append(blocks.pop())
        
        else:
            pile.append(blocks.popleft())
            
    if pile == sorted(pile, reverse=True):
        print('Yes')
    
    else:
        print('No')

# %%
##https://www.hackerrank.com/challenges/calendar-module/problem?isFullScreen=true&utm_campaign=challenge-recommendation&utm_medium=email&utm_source=24-hour-campaign


# Enter your code here. Read input from STDIN. Print output to STDOUT
import calendar

def dayOfDate(date):
    month= int(date.split(" ")[0])
    date_= int(date.split(" ")[1])
    year= int(date.split(" ")[2])
    #print(f"{year},{month},{date_}")
    week_Day_num=calendar.weekday(year, month, date_)
    week_days=[day for day in calendar.day_name]
    #print(week_days[week_Day_num].upper())
    return week_days[week_Day_num].upper()

if __name__=="__main__":
    date=input()
    week_days=dayOfDate(date)
    print(week_days)
# Out:
# 4

# %%
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.

# You may assume that each input would have exactly one solution, and you may not use the same element twice.

# You can return the answer in any order.

 

# Example 1:

# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:

# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:

# Input: nums = [3,3], target = 6
# Output: [0,1]

# %%
def twoSum(self, nums: List[int], target: int) -> List[int]:
    dict1={}
    for i,j in enumerate(nums):
        if (target-j) in dict1.keys():
            k=dict1[(target-j)]
            return [k,i]
        dict1[j]=i
    return -1

# %%
# Write a function to find the longest common prefix string amongst an array of strings.

# If there is no common prefix, return an empty string "".

 

# Example 1:

# Input: strs = ["flower","flow","flight"]
# Output: "fl"
# Example 2:

# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.
 

# Constraints:

# 1 <= strs.length <= 200
# 0 <= strs[i].length <= 200
# strs[i] consists of only lowercase English letters.

# %%
def longestCommonPrefix(self, strs: List[str]) -> str:
    min_len=min([len(i) for i in strs])
    if len(set(strs))==1:            
        return strs[0]
    elif min_len==1:
        #get the min len element
        smallest_string=list(filter(lambda x: len(x)==1,strs))[0]
        if sum([i.startswith(smallest_string) for i in strs])==len(strs):
            return smallest_string
        else:
            return ""

    else:
        prefix=""
        for i in range(min_len):
            if len(set([j[0:i+1] for j in strs]))==1:
                prefix=strs[0][0:i+1]
            else:
                break
        return prefix

# %%
longestCommonPrefix(["dog","racecar","car"])
# Out:
# else runs
# ''

# %%
sum([True,True,False])
# Out:
# 2

# %%
#https://www.hackerrank.com/challenges/map-and-lambda-expression/problem?isFullScreen=true&utm_campaign=challenge-recommendation&utm_medium=email&utm_source=7-day-campaign

cube = lambda x: x**3;# complete the lambda function 

def fibonacci(n):
    # return a list of fibonacci numbers
    fibb=[0,1]
    
    if n==0:
        return []
    elif n==1:
        return [0]
    
    elif n>2:
        while len(fibb)<n:
            fibb.append(sum(fibb[::-1][0:2]))
        return fibb
    else:
        return fibb
        
        

if __name__ == '__main__':
    n = int(input())
    print(list(map(cube, fibonacci(n))))

# %%
#https://www.hackerrank.com/challenges/introduction-to-regex/problem?utm_campaign=challenge-recommendation&utm_medium=email&utm_source=7-day-campaign

# %%
def checkIfFloat(num):
    #check if "." in number
    try:
        num=str(num)
        x=float(num)
        if "." in num:
            return True
        else:
            return False
    except:
        return False

# %% [markdown]
#  https://leetcode.com/problems/longest-common-prefix/description/
#
# ### 14. Longest Common Prefix
#
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string
#
# Example 1:
#
# Input: strs = ["flower","flow","flight"]
# Output: "fl"
# Example 2:
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.

# %%
from typing import List
def longestCommonPrefix(strs: List[str]) -> str:
    if len(strs)<=1:
        return ''
    min_len= min([len(i) for i in strs])
    prefix=''
    i=0
    while i<min_len:
        common_chars= set([j[:i] for j in strs])
        #print(common_chars)
        if len(common_chars)==1:
            prefix=strs[0][:i]
            i+=1
        else:
            break
    return prefix

# %%
longestCommonPrefix(["flower","flow","flight"])
# Out:
# 'fl'

# %%
longestCommonPrefix(["dog","racecar","car"])
# Out:
# ''

# %%
longestCommonPrefix([])
# Out:
# ''

# %%
longestCommonPrefix(['jjj'])
# Out:
# ''

# %% [markdown]
# ##### Optimal one
#  code implements the longestCommonPrefix function that takes a list of strings v as input and returns the longest common prefix of all the strings. Here is an explanation of how the code works:
#
# Initialize an empty string ans to store the common prefix.
# Sort the input list v lexicographically. This step is necessary because the common prefix should be common to all the strings, so we need to find the common prefix of the first and last string in the sorted list.
# Iterate through the characters of the first and last string in the sorted list, stopping at the length of the shorter string.
# If the current character of the first string is not equal to the current character of the last string, return the common prefix found so far.
# Otherwise, append the current character to the ans string.
# Return the ans string containing the longest common prefix.

# %%
def longestCommonPrefix(v: List[str]) -> str:
    ans=""
    v=sorted(v)
    first=v[0]
    last=v[-1]
    for i in range(min(len(first),len(last))):
        if(first[i]!=last[i]):
            return ans
        ans+=first[i]
    return ans

# %%
## https://www.hackerrank.com/challenges/most-commons/problem?isFullScreen=true

# Sample Input 

# aabbbccde

# Sample Output : Just 3 outputs top

# b 3
# a 2
# c 2
# Explanation 0


# Here, b occurs  times. It is printed first.
# Both a and c occur  times. So, a is printed in the second line and c in the third line because a comes before c in the alphabet.

def get_leter_count(s):
    unq_letters=set(s)
    dct={}
    for i in unq_letters:
        dct[i]= s.count(i)
    
    sorted_dct= dict(sorted(dct.items(),key=lambda item : (-item[1],item[0])))
    #print(list(sorted_dct.items())[:2])
    for key,value in list(sorted_dct.items())[:3]:
        print(f"{key} {value}")    
    #return sorted_dct

get_leter_count('aabbbccde')
# Out:
# b 3
# a 2
# c 2

# %%
get_leter_count('qwertyuiopasdfghjklzxcvbnm')
# Out:
# a 1
# b 1
# c 1

# %%
x="..."

# %%
get_leter_count(x)
# Out:
# a 419
# w 416
# y 415

# %% [markdown]
# https://leetcode.com/problems/merge-strings-alternately/description/?envType=study-plan-v2&envId=leetcode-75
#
# You are given two strings word1 and word2. Merge the strings by adding letters in alternating order, starting with word1. If a string is longer than the other, append the additional letters onto the end of the merged string.
#
# Return the merged string.
#
#
#
# Example 1:
#
# Input: word1 = "abc", word2 = "pqr"
# Output: "apbqcr"
# Explanation: The merged string will be merged as so:
# word1:  a   b   c
# word2:    p   q   r
# merged: a p b q c r
# Example 2:
#
# Input: word1 = "ab", word2 = "pqrs"
# Output: "apbqrs"
# Explanation: Notice that as word2 is longer, "rs" is appended to the end.
# word1:  a   b
# word2:    p   q   r   s
# merged: a p b q   r   s
# Example 3:
#
# Input: word1 = "abcd", word2 = "pq"
# Output: "apbqcd"
# Explanation: Notice that as word1 is longer, "cd" is appended to the end.
# word1:  a   b   c   d
# word2:    p   q
# merged: a p b q c   d
#
#
# Constraints:

# %%
def mergeAlternately( word1: str, word2: str) -> str:
    min_len=min([len(word1),len(word2)])
    result=""
    for i,j in  zip(word1[:min_len],word2[:min_len]):
       result+=i+j
    return result+word1[min_len:]+word2[min_len:]

# %%
word1 = "abcd" 
word2 = "pq"
mergeAlternately(word1,word2)
# Out:
# 'apbqcd'

# %%
word1 = "ab" 
word2 = "pqrs"
mergeAlternately(word1,word2)
# Out:
# 'apbqrs'

# %%
word1 = "abc" 
word2 = "pqr"
mergeAlternately(word1,word2)
# Out:
# 'apbqcr'

# %%
class Solution(object):
    def mergeAlternately(self, word1, word2):
        """
        :type word1: str
        :type word2: str
        :rtype: str
        """
        result = []
        i = 0
        while i < len(word1) or i < len(word2):
            if i < len(word1):
                result.append(word1[i])
            if i < len(word2):
                result.append(word2[i])
            i += 1
        return ''.join(result)

# %%
def gcd(a, b):
    
    # Everything divides 0
    if(a==0 or b==0):
        return max(a, b)
        
    # Find Minimum of a and b
    result = min(a, b)

    while result > 0:
        if a % result == 0 and b % result == 0:
            break
        result -= 1

    # Return gcd of a and b
    return result


if __name__ == '__main__':
    a = 20
    b = 28
    print(gcd(a, b))
# Out:
# 4

# %%
def gcd(a, b):
    
    # Everything divides 0
    if(a==0 or b==0):
        return max(a, b)
    while b:
        a,b=b,a%b
        print(a,b)
    return a
if __name__ == '__main__':
    a = 20
    b = 28
    print(gcd(a, b))
# Out:
# 28 20
# 20 8
# 8 4
# 4 0
# 4

# %% [markdown]
# #https://leetcode.com/problems/greatest-common-divisor-of-strings/?envType=study-plan-v2&envId=leetcode-75
#
# For two strings s and t, we say "t divides s" if and only if s = t + t + t + ... + t + t (i.e., t is concatenated with itself one or more times).
#
# Given two strings str1 and str2, return the largest string x such that x divides both str1 and str2.
#
#
#
# Example 1:
#
# Input: str1 = "ABCABC", str2 = "ABC"
#
# Output: "ABC"
#
# Example 2:
#
# Input: str1 = "ABABAB", str2 = "ABAB"
#
# Output: "AB"
#
# Example 3:
#
# Input: str1 = "LEET", str2 = "CODE"
#
# Output: ""
#
# Example 4:
#
# Input: str1 = "AAAAAB", str2 = "AAA"
#
# Output: ""​​​​​​​
#
#
#
# Constraints:
#
# 1 <= str1.length, str2.length <= 1000
# str1 and str2 consist of English uppercase letters.

# %%
def gcdOfStrings(str1: str, str2: str) -> str:
        if str1+str2 != str2+str1:
            #print("done")
            return ""
        len1,len2= len(str1),len(str2)
        while len2:
            len1,len2=len2,len1%len2
        gcd=len1
        #print(gcd)
        return str1[:gcd]

# %%
20%28
# Out:
# 20

# %%
# def gcd(a: int, b: int) -> int:
#     # Euclidean algorithm
#     while b:
#         a, b = b, a % b
#     return a

# def gcdOfStrings(str1: str, str2: str) -> str:
#     # Check if concatenations match
#     if str1 + str2 != str2 + str1:
#         return ""
    
#     # Use custom gcd function
#     gcd_len = gcd(len(str1), len(str2))
    
#     return str1[:gcd_len]

# # Example usage:
# print(gcdOfStrings("ABCABC", "ABC"))    # Output: "ABC"
# print(gcdOfStrings("ABABAB", "ABAB"))   # Output: "AB"
# print(gcdOfStrings("AAAAAB", "AAA"))    # Output: ""

# %%
str1 = "ABCABC"
str2 = "ABC"
gcdOfStrings(str1, str2)
# Out:
# 'ABC'

# %%
str1.split(str2)
# Out:
# ['', '', '']

# %%
str1 = "ABABAB"
str2 = "ABAB"
gcdOfStrings(str1, str2)
# Out:
# 'AB'

# %%
str1 = "AAAAAB"
str2 = "AAA"
gcdOfStrings(str1, str2)
# Out:
# ''

# %% [markdown]
# https://leetcode.com/problems/find-greatest-common-divisor-of-array/description/
#
# Given an integer array nums, return the greatest common divisor of the smallest number and largest number in nums.
#
# The greatest common divisor of two numbers is the largest positive integer that evenly divides both numbers.
#
#
#
# Example 1:
#
# Input: nums = [2,5,6,9,10]
# Output: 2
# Explanation:
# The smallest number in nums is 2.
# The largest number in nums is 10.
# The greatest common divisor of 2 and 10 is 2.
# Example 2:
#
# Input: nums = [7,5,6,8,3]
# Output: 1
# Explanation:
# The smallest number in nums is 3.
# The largest number in nums is 8.
# The greatest common divisor of 3 and 8 is 1.
# Example 3:
#
# Input: nums = [3,3]
# Output: 3
# Explanation:
# The smallest number in nums is 3.
# The largest number in nums is 3.
# The greatest common divisor of 3 and 3 is 3.
#
#
# Constraints:
#
# 2 <= nums.length <= 1000
# 1 <= nums[i] <= 1000

# %%
def findGCD(nums) -> int:
    min_num = min(nums)
    max_num = max(nums)

    for i in range(min_num, 0, -1):
        if min_num % i == 0 and max_num % i == 0:
            return i
    return 1

# %%
def findGCD(nums) -> int:
    min_num = min(nums)
    max_num = max(nums)

    while max_num:
        min_num, max_num = max_num, min_num % max_num
    return min_num

findGCD([2,5])
# Out:
# 1
