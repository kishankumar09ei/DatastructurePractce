# %%
print("Model S" , "Model 3" , sep="--")
# Out:
# Model S--Model 3

# %%
print("Model S" , "Model 3" , end="|")
# Out:
# Model S Model 3|

# %%
print("USA" , "France" , end="|")
# Out:
# USA France|
